# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/seazone-tech/jovens-talentos-2026-hackathon-data/refs/heads/master/data/Hosts_ids_Itapema.csv')
display(df.describe())
# Out:
# <bound method DataFrame.info of        owner_id           owner  is_superhost  number_of_reviews_host  \
# 0     167418369       Cristiane         False                     1.0
# 1     433162432         Adriana         False                    28.0
# 2     156933100           Carla         False                     0.0
# 3     175320187  Vitalino Ortiz          True                    38.0
# 4     108479878          Jarbas         False                   233.0
# ...         ...             ...           ...                     ...
# 4435  171984936       Ana Paula         False                     3.0
# 4436  226638643         Rogerio         False                    21.0
# 4437  493033982  Sônia Walfride         False                     6.0
# 4438  155369575          Silvio         False                     5.0
# 4439  381604431           Paulo         False                     1.0
#
#       is_verified  star_rating_host  years_host  months_host  \
# ...
